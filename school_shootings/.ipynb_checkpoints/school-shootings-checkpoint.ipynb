# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import pymysql
import sqlite3

import sys
import os as os
import subprocess
import shutil

# %%
def runcmd(cmd, verbose = False, *args, **kwargs):
    '''
    Function that runs a command in terminal directly from the notebook
    '''
    process = subprocess.Popen(
        cmd,
        stdout = subprocess.PIPE, 
        stderr = subprocess.PIPE,
        text = True, 
        shell = True
    )
    std_out, std_err = process.communicate()
    if verbose:
        print(std_out.strip(), std_err)
    pass

# %%
#init 
cwd=os.getcwd()
location=cwd+'/data'

print(cwd)
# Out:
# /Users/alialvarez/Desktop/STUDIES/github/code_library/school_shootings

# %% [markdown]
# # Obtaining Data

# %%
#downloading repository

try:
    os.remove(cwd+'/master.zip')
    
except OSError:
    pass

#download file
runcmd("wget https://github.com/ecodan/school-shooting-data/archive/refs/heads/master.zip", verbose = False)

#with 
source=os.path.join(os.getcwd(),'master.zip')
destination=os.path.join(os.getcwd(),'data','ecodan.zip')

#move to new location
shutil.move(source, destination)

#unzip
shutil.unpack_archive(destination, destination[:-4])

#remove zipfile
os.remove(destination)

# %% [markdown]
# # Reading Data

# %%
#read data

data_location=os.path.join(os.getcwd(),'data','ecodan','school-shooting-data-master')

#school schooting df
df_sc=pd.read_csv(data_location+'/pah_wikp_combo.csv')


#clean_data
df_sc=df_sc.drop(['Unnamed: 10', 'Unnamed: 11'], axis=1)

df_sc
# Out:
#           Date         City                 State  AreaType School  \
# 0    3/27/1990     Brooklyn              New York       NaN      C
# 1    5/20/1990  Centerville             Tennessee  suburban     HS
# 2    8/26/1990    Las Vegas                Nevada     urban     HS
# 3    9/11/1990  San Antonio                 Texas       NaN     HS
# 4     1/8/1991   Richardson                 Texas     urban     HS
# ..         ...          ...                   ...       ...    ...
# 739   4/5/2022         Erie          Pennsylvania       NaN     HS
# 740  4/22/2022   Washington  District of Columbia       NaN     HS
# 741   5/9/2022      Suwanee               Georgia       NaN    NaN
# 742  5/17/2022      Chicago              Illinois       NaN     ES
# 743  5/24/2022       Uvalde                 Texas       NaN     ES
#
#      Fatalities  Wounded Dupe Source  \
# 0             0      1.0  NaN   Wikp
# 1             1      NaN  NaN    Pah
# 2             1      NaN  NaN    Pah
# 3             0      3.0  NaN   Wikp
# 4             0      NaN  NaN    Pah
# ..          ...      ...  ...    ...
# 739           0      1.0  NaN    NaN
# 740           0      4.0  NaN    NaN
# 741           0      1.0  NaN    NaN
# 742           0      1.0  NaN    NaN
# 743          22     15.0  NaN    NaN
#
#                                                   Desc
# 0    A black youth was taunted with racial slurs by...
# 1                                                  NaN
# 2                                                  NaN
# 3    3 students were wounded when gunfire broke out...
# 4                                                  NaN
# ..                                                 ...
# 739  A student was wounded after multiple shots wer...
# 740  A resident of an adjacent apartment building f...
# 741  A woman fired 12 shots at a moving school bus....
# 742  An 8-year old child found his mother's gun und...
# 743  Robb Elementary School shooting: An 18-year-ol...
#
# [744 rows x 10 columns]

# %% [markdown]
# # Cleaning Data

# %%
#checking for nulls
# missing data
((df_sc
 .isna()
 .mean()
 *100)
 .pipe(lambda ser:ser[ser>0])
)
# Out:
# AreaType    48.790323
# School       0.268817
# Wounded     51.209677
# Dupe        81.451613
# Source       4.973118
# Desc        51.478495
# dtype: float64

# %%
df_sc.describe()
# Out:
#        Fatalities     Wounded
# count  744.000000  363.000000
# mean     1.141129    1.942149
# std      2.756170    3.288094
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      1.000000    1.000000
# 75%      1.000000    2.000000
# max     33.000000   23.000000

# %%
(df_sc['Fatalities']
 .value_counts()
.plot(kind="bar")
)
# Out:
# <AxesSubplot:>

# %%
df_sc.dtypes
# Out:
# Date           object
# City           object
# State          object
# AreaType       object
# School         object
# Fatalities      int64
# Wounded       float64
# Dupe           object
# Source         object
# Desc           object
# dtype: object

# %%
#Renaiming States 
state=df_sc.State.replace({'District Of Columbia':'D.C.', 'District of Columbia':'D.C.', 'IA':'Indiana'})
df_sc=df_sc.drop('State', axis=1)
df_sc=pd.concat([df_sc, state], axis=1)
df_sc
# Out:
#           Date         City  AreaType School  Fatalities  Wounded Dupe Source  \
# 0    3/27/1990     Brooklyn       NaN      C           0      1.0  NaN   Wikp
# 1    5/20/1990  Centerville  suburban     HS           1      NaN  NaN    Pah
# 2    8/26/1990    Las Vegas     urban     HS           1      NaN  NaN    Pah
# 3    9/11/1990  San Antonio       NaN     HS           0      3.0  NaN   Wikp
# 4     1/8/1991   Richardson     urban     HS           0      NaN  NaN    Pah
# ..         ...          ...       ...    ...         ...      ...  ...    ...
# 739   4/5/2022         Erie       NaN     HS           0      1.0  NaN    NaN
# 740  4/22/2022   Washington       NaN     HS           0      4.0  NaN    NaN
# 741   5/9/2022      Suwanee       NaN    NaN           0      1.0  NaN    NaN
# 742  5/17/2022      Chicago       NaN     ES           0      1.0  NaN    NaN
# 743  5/24/2022       Uvalde       NaN     ES          22     15.0  NaN    NaN
#
#                                                   Desc         State
# 0    A black youth was taunted with racial slurs by...      New York
# 1                                                  NaN     Tennessee
# 2                                                  NaN        Nevada
# 3    3 students were wounded when gunfire broke out...         Texas
# 4                                                  NaN         Texas
# ..                                                 ...           ...
# 739  A student was wounded after multiple shots wer...  Pennsylvania
# 740  A resident of an adjacent apartment building f...          D.C.
# 741  A woman fired 12 shots at a moving school bus....       Georgia
# 742  An 8-year old child found his mother's gun und...      Illinois
# 743  Robb Elementary School shooting: An 18-year-ol...         Texas
#
# [744 rows x 10 columns]

# %% [markdown]
# # Creating SQL Table

# %%
def run_query(q):
    c.execute(q)

    #extract columns
    column_names=[]
    columns = c.description
    for i in columns: column_names.append(i[0])

    #print
    df_q = pd.DataFrame(c.fetchall(), columns=column_names).set_index(column_names[0]) 
    return df_q

# %%
conn = sqlite3.connect('db_sch_sch')
c = conn.cursor()

c.execute('CREATE TABLE IF NOT EXISTS shootings (Date, City, State, AreaType, School, Fatalities, Wounded, Dupe, Source, Desc)')
conn.commit()
df_sc.to_sql('shootings', conn, if_exists='replace', index = False)
 
q=('''  
SELECT * FROM shootings
          ''')
run_query(q)
# Out:
#                             City  AreaType School  Fatalities  Wounded  Dupe  \
# Date
# 1990-03-27 00:00:00     Brooklyn      None      C           0      1.0   NaN
# 1990-05-20 00:00:00  Centerville  suburban     HS           1      NaN   NaN
# 1990-08-26 00:00:00    Las Vegas     urban     HS           1      NaN   NaN
# 1990-09-11 00:00:00  San Antonio      None     HS           0      3.0   NaN
# 1991-01-08 00:00:00   Richardson     urban     HS           0      NaN   NaN
# ...                          ...       ...    ...         ...      ...   ...
# 2022-04-05 00:00:00         Erie      None     HS           0      1.0   NaN
# 2022-04-22 00:00:00   Washington      None     HS           0      4.0   NaN
# 2022-05-09 00:00:00      Suwanee      None   None           0      1.0   NaN
# 2022-05-17 00:00:00      Chicago      None     ES           0      1.0   NaN
# 2022-05-24 00:00:00       Uvalde      None     ES          22     15.0   NaN
#
#                     Source                                               Desc  \
# Date
# 1990-03-27 00:00:00   Wikp  A black youth was taunted with racial slurs by...
# 1990-05-20 00:00:00    Pah                                               None
# 1990-08-26 00:00:00    Pah                                               None
# 1990-09-11 00:00:00   Wikp  3 students were wounded when gunfire broke out...
# 1991-01-08 00:00:00    Pah                                               None
# ...                    ...                                                ...
# 2022-04-05 00:00:00   None  A student was wounded after multiple shots wer...
# 2022-04-22 00:00:00   None  A resident of an adjacent apartment building f...
# 2022-05-09 00:00:00   None  A woman fired 12 shots at a moving school bus....
# 2022-05-17 00:00:00   None  An 8-year old child found his mother's gun und...
# 2022-05-24 00:00:00   None  Robb Elementary School shooting: An 18-year-ol...
#
#                             State  Year
# Date
# 1990-03-27 00:00:00      New York  1990
# 1990-05-20 00:00:00     Tennessee  1990
# 1990-08-26 00:00:00        Nevada  1990
# 1990-09-11 00:00:00         Texas  1990
# 1991-01-08 00:00:00         Texas  1991
# ...                           ...   ...
# 2022-04-05 00:00:00  Pennsylvania  2022
# 2022-04-22 00:00:00          D.C.  2022
# 2022-05-09 00:00:00       Georgia  2022
# 2022-05-17 00:00:00      Illinois  2022
# 2022-05-24 00:00:00         Texas  2022
#
# [744 rows x 10 columns]

# %% [markdown]
# ### Trending Fatalities per State

# %%
#ttrending fatalities per state

#prepare data
df_q=df_sc
df_q['Date']= pd.to_datetime(df['Date'])
df_q['Year']=(
    df_q.Date.dt.year
)

#modify table schema with new columns
c.execute('CREATE TABLE IF NOT EXISTS shootings (Date, City, State, AreaType, School, Fatalities, Wounded, Dupe, Source, Desc, Year)')
conn.commit()

#update data
df_q.to_sql('shootings', conn, if_exists='replace', index = False)

#query
q=(
'''
SELECT
  Year, 
  State, 
  Fatalities
FROM shootings
'''
)

df_graph=run_query(q)

print(df_graph)
# Out:
#              State  Fatalities
# Year
# 1990      New York           0
# 1990     Tennessee           1
# 1990        Nevada           1
# 1990         Texas           0
# 1991         Texas           0
# ...            ...         ...
# 2022  Pennsylvania           0
# 2022          D.C.           0
# 2022       Georgia           0
# 2022      Illinois           0
# 2022         Texas          22
#
# [744 rows x 2 columns]

# %%
#graphic above 

#y variable
from datetime import date
current_year = date.today().year
y=pd.Series(range(1990,current_year, 1))



df_graph=df_graph.reset_index()

#obtain data for each state
all_d=[]
s=df_graph.State.unique()
# for state in s:
for year in y: 
    d=[]
    for row in df_graph.itertuples(Year==year, State='Texas'):
        print(row)
#         d.append(row)
#     print(d)
    
#     df_state=df_graph[df_graph.State=='Texas'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [278], in <cell line: 16>()
#      16 for year in y:
#      17     d=[]
# ---> 18     for row in df_graph.itertuples(Year==year, State='Texas'):
#      19         print(row)
#
# NameError: name 'Year' is not defined

# %% [markdown]
# ### Known Shooter Profile (Age)

# %%
#obtain data
import re

df_q=(
    pd.Series(df_sc['Desc'][:])
    .fillna("")
)
l=[]
regex=re.compile(r"(\b([0-9]|[1-9][0-9])\b-year-old)")

for row in df_q:
    if row !="":
        try:
            x=re.search(regex, row)
            x=str(x).split('=')[2].replace('-',' ')
            x=re.sub("[''>]",'',x)
            l.append(x)
        except:
            l.append(np.nan)
    else:
        l.append(np.nan)
        

df_sc['probable_shooter_age']=l
print(df_sc)
# Out:
#           Date         City                 State  AreaType School  \
# 0    3/27/1990     Brooklyn              New York       NaN      C
# 1    5/20/1990  Centerville             Tennessee  suburban     HS
# 2    8/26/1990    Las Vegas                Nevada     urban     HS
# 3    9/11/1990  San Antonio                 Texas       NaN     HS
# 4     1/8/1991   Richardson                 Texas     urban     HS
# ..         ...          ...                   ...       ...    ...
# 739   4/5/2022         Erie          Pennsylvania       NaN     HS
# 740  4/22/2022   Washington  District of Columbia       NaN     HS
# 741   5/9/2022      Suwanee               Georgia       NaN    NaN
# 742  5/17/2022      Chicago              Illinois       NaN     ES
# 743  5/24/2022       Uvalde                 Texas       NaN     ES
#
#      Fatalities  Wounded Dupe Source  \
# 0             0      1.0  NaN   Wikp
# 1             1      NaN  NaN    Pah
# 2             1      NaN  NaN    Pah
# 3             0      3.0  NaN   Wikp
# 4             0      NaN  NaN    Pah
# ..          ...      ...  ...    ...
# 739           0      1.0  NaN    NaN
# 740           0      4.0  NaN    NaN
# 741           0      1.0  NaN    NaN
# 742           0      1.0  NaN    NaN
# 743          22     15.0  NaN    NaN
#
#                                                   Desc probable_shooter_age
# 0    A black youth was taunted with racial slurs by...          14 year old
# 1                                                  NaN                  NaN
# 2                                                  NaN                  NaN
# 3    3 students were wounded when gunfire broke out...          17 year old
# 4                                                  NaN                  NaN
# ..                                                 ...                  ...
# 739  A student was wounded after multiple shots wer...                  NaN
# 740  A resident of an adjacent apartment building f...                  NaN
# 741  A woman fired 12 shots at a moving school bus....                  NaN
# 742  An 8-year old child found his mother's gun und...          28 year old
# 743  Robb Elementary School shooting: An 18-year-ol...          18 year old
#
# [744 rows x 11 columns]

# %% [markdown]
# ### Known Shooter Profile (AreaType)

# %% [markdown]
# ### Shootings per State (per capita)

# %% [markdown]
# ## Finished Plots

# %% [markdown]
# ### Fatalities per Type of School

# %%
q=(
'''
SELECT
    DISTINCT(School),
    SUM(Fatalities) as Tot_fatalities
FROM shootings
GROUP BY School
ORDER BY Tot_fatalities DESC
'''
)
data=run_query(q)
print(data)


#reordering columns based on education level
data=pd.DataFrame(data, columns=['Tot_fatalities'],index=['C', 'HS', 'MS', 'ES'])

data=(data
    .reset_index())
data.rename(columns={data.columns[0]:'School'}, inplace=True)

#graph
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(13,5), sharex=True)
ax=(data
    .plot(x='School', kind = 'bar',alpha=0.6, ax=ax) 
)

# print(data.reset_index().)
# Out:
#         Tot_fatalities
# School
# HS                 390
# C                  263
# ES                 123
# MS                  65
# -                    7
# None                 1

# %% [markdown]
# ### Total Victims (Fatalities + Wounded)

# %%
q=(
'''
SELECT
    DISTINCT(State),
    SUM(Fatalities +Wounded) as Tot_victims
FROM shootings
GROUP BY State
ORDER BY Tot_victims DESC
'''
)
data=run_query(q)
print(data[:10])

#graph
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(13,5), sharex=True)

ax=(data
    .reset_index()
    .plot(x='State', kind = 'bar',alpha=0.6, ax=ax))
# Out:
#               Tot_victims
# State
# California          140.0
# Texas                98.0
# Virginia             80.0
# Florida              66.0
# Oregon               55.0
# Colorado             54.0
# Illinois             46.0
# Michigan             45.0
# Pennsylvania         42.0
# Georgia              37.0

# %% [markdown]
# ### Top 10 States with fatalities since 1990

# %%
#Top 10 States with fatalities since 1990 
q=(
'''
SELECT
    DISTINCT(State),
    SUM(Fatalities) as Tot_fatalities
FROM shootings
GROUP BY State
ORDER BY Tot_fatalities DESC
'''
)
data=run_query(q)
print(data[:10])

#graph
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(13,5), sharex=True)

ax=(data
    .reset_index()
    .plot(x='State', kind = 'bar',alpha=0.6, ax=ax,) 
   )
# Out:
#               Tot_fatalities
# State
# California               102
# Virginia                  76
# Texas                     66
# Connecticut               57
# Florida                   46
# Colorado                  38
# Pennsylvania              32
# Washington                31
# Minnesota                 26
# Oregon                    23
